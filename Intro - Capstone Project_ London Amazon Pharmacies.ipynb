# %% [markdown]
# # IBM Data Science Capstone Project: London Amazon Pharmacies

# %% [markdown]
# ## Commercial real estate insights for Amazon's new pharmacy initiative in London

# %% [markdown]
# ### Introduction

# %% [markdown]
# <p>During the COVID19 pandemic, a number of commercial venues have foreclosed due to the economic downturn from the lockdowns in London.</p>
# <p>Given that London's commercial real estate market is extremely expensive, the recent foreclosures represent a unique buying opportunity in central London.</p>
# <p>Amazon has recently launched their online pharmacy in the US on 17th November 2020 and have also secured their patent to operate in the UK this year. Their online pharmacies allow customers to purchase their medication on the Amazon online marketplace and get it delivered to their home address extremely conveniently, without ever having to leave their home. This is a highly disruptive move against the brick and mortar pharmacy sector.</p>
#
#    <br>
# <p>However, unlike industries such as grocery or automotive, many pharmaceutical manufacturers don't have the luxury of serving a mass market. Orders are often smaller, more individualized, and more last-minute in nature than in other business sectors. Moreover, professionals working in the medical device industry can't as readily predict exactly where or when their materials will be needed.</p> <p>As a result, Amazon needs distribution centers that offer optimal reach and flexibility, compared to their larger distribution centers.</p>
#    <br>
#   <p>Therefore, this is a opportunistic time for Amazon to move into central London's commercial real estate market under the assumption that prices should now be a lot lower than before the COVID19 pandemic in order to build smaller distribution centers closer to their customers. This will allow them to offer a leap in value over the existing brick and mortar pharmacies within the city center.</p>

# %% [markdown]
# ### Business Problem

# %% [markdown]
# <p>Amazon has now decided to buy commercial real estate to build their online pharmacy distribution centers. But, the problem is an exercise in cost-effectiveness. They want to get the most bang for their buck, as they say.</p> <br><p>Therefore, they would like some insight into the following:</p>
# <ul>
#     <li>What is the optimum number of distribution centers, k?</li>
#     <li>What is the maximum reach area they can attain with, k, number of disitribution centers?</li>
#     <li>What are the specific locations they should target for the, k, distribution centers?</li>
#     </ul>

# %% [markdown]
# ### Analytic Approach
#
# <p> The analytical approach to solving this problem would involve generating and visualising geospatial data using Geocoder and Folium. Using K-means clustering with KMeans to find the insights. Geocoder, Folium and KMeans are free libraries on Python.</p>

# %% [markdown]
# ### Data requirements

# %% [markdown]
# The data we require to generate these insights are listed below:
#
#
# #### Foursquare location data API
# <p> This problem will be solved using the Foursquare location data API.</p>
# <p>The specific data which will be used from the Foursquare API is:</p>
# <ul>
#     <li>Venue location data</li>
#     <li>Venue category data</li>
#     <li>Venue opening hours data</li>
#     </ul>
#    <br>
#
# #### London data store
#    <p> We will also use the Ordnance Survey Code-Point Open provied by the Greater London Authority for postcode, borough and neighbourhood data.</p>
#    <p> Found here: https://data.london.gov.uk/dataset/ordnance-survey-code-point</p>
